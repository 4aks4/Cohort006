# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 32561 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
salaries = pd.read_csv('adult_eda.csv')
salaries
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
# Your Code is Here

salaries.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qFn8RZs/US-Citicens1.png)

# %%
# Your Code is Here

salaries.shape
# Out:
# (32561, 15)

# %% [raw]
# Desired Output:
#
# (32561, 15)

# %%
# Your Code is Here

salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
# Check if the Dataset have any Duplicate

# Your Code is Here

salaries.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %% [raw]
# Desired Output:
#
# False    32537
# True        24
# dtype: int64

# %%
# Drop Duplicates

# Your Code is Here

salaries = salaries.drop_duplicates()

# %%
# Check the shape of the Dataset

# Your Code is Here

salaries.shape
# Out:
# (32537, 15)

# %% [raw]
# Desired Output:
#
# (32537, 15)

# %%
# Your Code is Here

salaries.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %%
salaries['capital-gain'].value_counts()
# Out:
# 0        29825
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: capital-gain, Length: 119, dtype: int64

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/HnG6Xdn/US-Citicens2.png)

# %% [markdown]
# **Rename the features of;**<br>
# **``"education-num"``**, **``"marital-status"``**, **``"capital-gain"``**, **``"capital-loss"``**, **``"hours-per-week"``**, **``"native-country"``** **as**<br>
# **``"education_num"``**, **``"marital_status"``**, **``"capital_gain"``**, **``"capital_loss"``**, **``"hours_per_week"``**, **``"native_country"``**, **respectively and permanently.**

# %%
# Your Code is Here
old = ["education-num", "marital-status","capital-gain", "capital-loss","hours-per-week","native-country"]
new = ["education_num", "marital_status","capital_gain", "capital_loss","hours_per_week","native_country"]
column_dict = dict(zip(old, new))
column_dict
salaries = salaries.rename(columns=column_dict)
salaries.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# Check the sum of Missing Values per column

# Your Code is Here

salaries.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %% [raw]
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# gender               0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values

# Your Code is Here

salaries.isnull().sum()*100/len(salaries)
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# sex               0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [raw]
# Desired Output:
#
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# gender            0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
# Your Code is Here

salaries.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %% [raw]
# Desired Output:
#
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# Your Code is Here
# .decribe for object data type
salaries.describe(include='object').T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/WspBGfZ/US-Citicens3.png)

# %% [markdown]
# **Assign the Columns (Features) of object data type as** **``"object_col"``**

# %%
# Your Code is Here

object_col = salaries.describe(include='object').columns
object_col
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %% [raw]
# Desired Output:
#
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'gender', 'native_country', 'salary'],
#       dtype='object')

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(salaries[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64
# ----------------------------------------
# occupation
# ----------------
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64
# ----------------------------------------
# relationship
# ----------------
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64
# ----------------------------------------
# race
# ----------------
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64
# ----------------------------------------
# sex
# ----------------
# Male      21775
# Female    10762
# Name: sex, dtype: int64
# ----------------------------------------
# native_country
# ----------------
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64
# ----------------------------------------
# salary
# ----------------
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64
# ----------------------------------------

# %% [markdown]
# **Check if the Dataset has any Question Mark** **``"?"``**

# %%
# Your Code is Here

salaries.isin(['?']).any() # .any() bring here the true for the ones that have it and false for the ones that don't
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [raw]
# Desired Output:
#
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# gender            False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## In data analysis, features (also known as variables or columns) in a dataset can be broadly classified into two types: numeric and categorical. Here are the differences between these two types of features:
#
# ## Numeric Features:
#
# - Numeric features represent values that can be measured or quantified.
# - Numeric features can be either continuous or discrete.
# - Examples of numeric features include age, height, weight, temperature, and income.
# - Numeric features can be used to perform mathematical or statistical calculations, such as computing the mean,     median, standard deviation, or correlation between different variables.
# - Numeric features are often analyzed using histograms, scatter plots, or box plots.
# ## Categorical Features:
#
# - Categorical features represent values that cannot be measured or quantified.
# - Categorical features can be nominal (unordered) or ordinal (ordered).
# - Examples of categorical features include gender, color, occupation, education level, and political affiliation.
# - Categorical features can be used to group or classify data based on shared characteristics or attributes.
# - Categorical features are often analyzed using bar charts, pie charts, or frequency tables.
#
#
# - In general, the differences between numeric and categorical features in data analysis reflect the fact that numeric features can be treated as continuous variables that can take on any value within a range, while categorical features are often treated as discrete variables that can only take on a limited number of values or categories. Understanding the type of features in a dataset is important for selecting appropriate analysis techniques and visualizations to explore and communicate the data.

# %% [markdown]
# ## Salary (Target Feature)

# %% [markdown]
# **Check the count of person in each "salary" levels and visualize it with a countplot**

# %%
# Your Code is Here

type(str(salaries.salary.value_counts()[1]))
# Out:
# str

# %% [raw]
# Desired Output:
#
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
# Your Code is Here
ax = sns.barplot(x=salaries.salary.value_counts().index, y=salaries.salary.value_counts().values)
for i in ax.patches:
    ax.annotate(int(i.get_height()),(i.get_x()+0.3, i.get_height()+1
                                     ))

# plt.xticks(rotation=5)
plt.ylabel('Count')
plt.xlabel('Salary')
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9qwrtB1/US-Citicens4.png)

# %% [markdown]
# **Check the percentage of person in each "salary" levels and visualize it with a pieplot**

# %%
# Your Code is Here

salaries.salary.value_counts()*100/len(salaries)
# Out:
# <=50K   75.907
# >50K    24.093
# Name: salary, dtype: float64

# %% [raw]
# Desired Output:
#
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
# Your Code is Here
colors = ['lightskyblue', 'gold']
labels = [str(salaries.salary.value_counts().index[0]), str(salaries.salary.value_counts().index[1])]
explode_list = [0.0,0.1]

ax = plt.pie(x=salaries.salary.value_counts()*100/len(salaries), 
             colors=colors,
             autopct='%1.1f%%',
             labels=labels,
             explode=explode_list,
             shadow=True)

plt.title('Percentage of Income-Levels');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/8YFvBrq/US-Citices5.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** The information provided by this chart shows that a quarter of the people how higher salaries thatn 50k. However, a staggering %75.9 of people are working for a salary lower than 50k.

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ## age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(x=salaries.age);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JKKwy5K/US-Citizens6.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
salaries.age.value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    876
# 33    875
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: age, Length: 73, dtype: int64

# %%
# Your Code is Here

sns.histplot(x=salaries.age, bins=20, kde=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JcJ9cyp/US-Citizens7.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here
salaries.age.describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(x= 'salary', y='age', data=salaries);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/64tBVNT/US-Citizens8.png)

# %%
# Your Code is Here

sns.histplot(x=salaries.age, hue=salaries.salary, bins=20, kde=True );

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/q5P0sVf/US-Citizens9.png)

# %%
# Your Code is Here

sns.kdeplot(x=salaries.age, hue=salaries.salary, fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7Y2HkxB/US-Citizens10.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

salaries.groupby('salary').describe()['age']
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %%
salaries.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xYYZcZZ/US-Citizens11.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**
# According to the available information, the age group for people paid under 50k is younger than the people who earn more. However, both groups have outliers.

# %% [markdown]
# ## fnlwgt

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
salaries.fnlwgt
# Out:
# 0         77516
# 1         83311
# 2        215646
# 3        234721
# 4        338409
#           ...
# 32556    257302
# 32557    154374
# 32558    151910
# 32559    201490
# 32560    287927
# Name: fnlwgt, Length: 32537, dtype: int64

# %%
# Your Code is Here

sns.boxplot(x=salaries.fnlwgt); # we must pass the x when we are creating a box and whiskers plot.

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x2TtkzH/US-Citizens12.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.histplot(x=salaries.fnlwgt, bins=30, kde=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/ZmMV8nv/US-Citizens13.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

salaries.fnlwgt.describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [raw]
# Desired Output:
#
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(x='salary', y='fnlwgt', data=salaries);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/ZxJS7JW/US-Citizens14.png)

# %%
salaries.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# Your Code is Here

sns.kdeplot(x='fnlwgt', hue='salary', data=salaries, fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TgygLrz/US-Citizens15.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

salaries.groupby('salary').describe()['fnlwgt']
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/LzWqdBf/US-Citizens16.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Can't get a result based on the data. Insufficient data.

# %% [markdown]
# ## capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here
sns.boxplot(x=salaries.capital_gain);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6Xj1TCz/US-Citizens17.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(x=salaries.capital_gain, fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/X3nW72Q/US-Citizens18.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

salaries.capital_gain.describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(x='salary', y='capital_gain', data=salaries);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/CM3cTgt/19.png)

# %%
# Your Code is Here

sns.kdeplot(x='capital_gain', hue='salary', data=salaries, fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/h7DKvLY/20.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here
salaries.groupby('salary').describe()['capital_gain']
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %%
salaries.capital_gain.value_counts().head(30)*100/len(salaries.capital_gain)
# Out:
# 0       91.665
# 15024    1.066
# 7688     0.873
# 7298     0.756
# 99999    0.489
# 5178     0.298
# 3103     0.298
# 4386     0.215
# 5013     0.212
# 8614     0.169
# 3325     0.163
# 2174     0.148
# 10520    0.132
# 4064     0.129
# 14084    0.126
# 4650     0.126
# 3137     0.114
# 20051    0.114
# 27828    0.104
# 594      0.104
# 3908     0.098
# 2829     0.095
# 13550    0.083
# 6849     0.083
# 14344    0.080
# 1055     0.077
# 2885     0.074
# 3411     0.074
# 2176     0.071
# 4787     0.071
# Name: capital_gain, dtype: float64

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mzYxTD4/21.png)

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %%
# Your Code is Here

salaries[salaries.capital_gain !=0].groupby('salary').describe()['capital_gain']
x = salaries[salaries.capital_gain !=0]
x
# Out:
#        age         workclass  fnlwgt    education  education_num  \
# 0       39         State-gov   77516    Bachelors         13.000
# 8       31           Private   45781      Masters         14.000
# 9       42           Private  159449    Bachelors         13.000
# 59      30           Private  188146      HS-grad          9.000
# 60      30           Private   59496    Bachelors         13.000
# ...    ...               ...     ...          ...            ...
# 32515   66       Federal-gov   47358         10th          6.000
# 32518   57         Local-gov  110417      HS-grad          9.000
# 32538   38           Private  139180    Bachelors         13.000
# 32548   65  Self-emp-not-inc   99359  Prof-school         15.000
# 32560   52      Self-emp-inc  287927      HS-grad          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 8           Never-married     Prof-specialty  Not-in-family  White  Female
# 9      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 59     Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 60     Married-civ-spouse              Sales        Husband  White    Male
# ...                   ...                ...            ...    ...     ...
# 32515  Married-civ-spouse       Craft-repair        Husband  White    Male
# 32518  Married-civ-spouse       Craft-repair        Husband  White    Male
# 32538            Divorced     Prof-specialty      Unmarried  Black  Female
# 32548       Never-married     Prof-specialty  Not-in-family  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary
# 0              2174             0              40  United-States  <=50K
# 8             14084             0              50  United-States   >50K
# 9              5178             0              40  United-States   >50K
# 59             5013             0              40  United-States  <=50K
# 60             2407             0              40  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 32515          3471             0              40  United-States  <=50K
# 32518         99999             0              40  United-States   >50K
# 32538         15020             0              45  United-States   >50K
# 32548          1086             0              60  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [2712 rows x 15 columns]

# %%
sns.boxplot(x='capital_gain', y='salary', data=x);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/r3mdBkK/22.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** According to this information, 91% of the people are not eligible for a captial gain.

# %% [markdown]
# ## capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(x=salaries.capital_loss);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Db3XHKz/23.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(salaries.capital_loss, fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/z7P15zX/24.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

salaries.capital_gain.describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(x='salary', y='capital_loss', data=salaries);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Dr7Bv9V/25.png)

# %%
# Your Code is Here

sns.kdeplot(x='capital_loss', hue='salary', data=salaries, fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4Vg5Zyy/26.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

salaries.groupby('salary').describe()['capital_loss']
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/h9DTKNW/27.png)

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %%
# Your Code is Here

x = salaries[salaries.capital_loss != 0]
x.groupby('salary')['capital_loss'].describe()
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/gJzQvmD/28.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Based on this information, most people didn't experience a capital loss.

# %% [markdown]
# ## hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(x=salaries.hours_per_week)
# Out:
# <Axes: xlabel='hours_per_week'>

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TkNCRYY/29.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
fig, ax = plt.subplots(figsize=(6,4))

sns.kdeplot(x=salaries.hours_per_week, fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/tsp5GXb/30.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

salaries.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
fig, ax = plt.subplots(figsize=(6,4))

sns.boxplot(x='salary', y='hours_per_week', data=salaries);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4RhSct7/31.png)

# %%
# Your Code is Here
fig, ax = plt.subplots(figsize=(6,4))
sns.kdeplot(x=salaries.hours_per_week, hue=salaries.salary, fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/pbbVnMG/32.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

salaries.groupby('salary').describe()['hours_per_week']
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6NbWfzz/33.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** .....................

# %%
salaries.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
sns.scatterplot(x='capital_gain', y='race', hue='salary', s=200, data=salaries)
# Out:
# <Axes: xlabel='capital_gain', ylabel='race'>

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education_num   31735 non-null  float64
#  5   marital_status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    27473 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital_gain    32537 non-null  int64
#  11  capital_loss    32537 non-null  int64
#  12  hours_per_week  32537 non-null  int64
#  13  native_country  32537 non-null  object
#  14  salary          32537 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 4.0+ MB

# %%
# Your Code is Here

num = salaries.select_dtypes(include=[float, int])
custom_palette = sns.color_palette(["green", "lightgreen"])
relation = sns.pairplot(salaries, diag_kind="kde", 
                        hue='salary',
                        corner=True,
                        palette=custom_palette
                        )
relation
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/N7Fz4hg/34.png)

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

salaries.education.value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %% [raw]
# Desired Output:
#
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
# Your Code is Here

salaries.education_num.value_counts()
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %% [raw]
# Desired Output:
#
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
# Your Code is Here

categ = salaries.groupby(['education','education_num'], 
                         dropna=False).size()

# %% [raw]
# Desired Output:
#
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# Masters       14.000            1686
#               NaN                 36
# Preschool     1.000               49
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7089
#               NaN                193
# Name: education_num, dtype: int64

# %% [raw]
# categ_df = categ.reset_index('education_num')
# categ_df

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))

sns.countplot(x=salaries.education)

# for i in ax.patches:
#     ax.annotate(int(i.get_height()),(i.get_x()+0.3, i.get_height()+1
#                                      ))

plt.xticks(rotation=90)
plt.yticks(rotation=0, fontsize=7)
plt.ylabel('Count')
plt.xlabel('Education')
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5xc31HR/35.png)

# %%
# Your Code is Here


fig, ax = plt.subplots(figsize=(5.5,4))

sns.countplot(x=salaries.education_num)

# for i in ax.patches:
#     ax.annotate(int(i.get_height()),(i.get_x()+0.3, i.get_height()+1
#                                      ))

plt.xticks(rotation=0)
plt.yticks(rotation=0, fontsize=7)
plt.ylabel('Count')
plt.xlabel('Education Number')
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6HWtNN6/36.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
# Your Code is Here

salaries.groupby(['education', 'salary']).size()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     <=50K      107
#               >50K       306
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       <=50K      763
#               >50K       959
# Preschool     <=50K       50
# Prof-school   <=50K      153
#               >50K       423
# Some-college  <=50K     5896
#               >50K      1386
# dtype: int64

# %% [raw]
# Desired Output:
#
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# Name: salary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))

sns.countplot(x='education', hue='salary', data=salaries)
plt.xticks(rotation=90, fontsize=7)
plt.yticks(rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=6)
plt.xlabel('Education', fontsize=6)
plt.legend(loc='upper center', fontsize=8, title='salary', title_fontsize=8)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qxZXX1y/37.png)

# %%
# Your Code is Here

salaries.groupby(['education_num', 'salary']).size()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         <=50K      751
#                >50K       935
# 15.000         <=50K      149
#                >50K       410
# 16.000         <=50K      103
#                >50K       302
# dtype: int64

# %% [raw]
# Desired Output:
#
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
#                <=50K      103
# Name: salary, dtype: int64

# %%
# Your Code is Here
fig, ax = plt.subplots(figsize=(5.5,4))

sns.countplot(x='education_num', hue='salary', data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Education_num', fontsize=7)
plt.legend(loc='upper right', fontsize=7, title='salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/2M0BYyk/38.png)

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))

sns.boxplot(x='salary', 
            y='education_num', 
            data=salaries,
            fliersize=3)
plt.xticks(rotation=0, fontsize=7)
start = 0
end = 16
steps = 9
yticks = np.linspace(start, end, steps)
plt.yticks(yticks,rotation=0, fontsize=7)

plt.ylabel('Education Number', fontsize=7)
plt.xlabel('Salary', fontsize=7)
# plt.legend(loc='upper right', fontsize=7, title='salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mSBNzKw/39.png)

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
# Your Code is Here

salaries['education'].apply(mapping_education).value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %% [raw]
# Desired Output:
#
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
# By using "mapping_education" def function above, create a new column named "education_summary"

# Your Code is Here

salaries['education_level'] = salaries['education'].apply(mapping_education)

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 20000
steps = 9
yticks = np.linspace(start, end, steps)
sns.countplot(x='education_level', data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)

plt.ylabel('Count', fontsize=7)
plt.xlabel('Education Level', fontsize=7)
plt.legend(loc='upper right', fontsize=7, title='salary', title_fontsize=7)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cx3Dzn1/40.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %%
# Your Code is Here
salaries.groupby(['education_level', 'salary']).size()
# Out:
# education_level     salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# dtype: int64

# %% [raw]
# Desired Output:
#
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 16000
steps = 9
yticks = np.linspace(start, end, steps)
sns.countplot(x='education_level', 
              hue='salary', 
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Education Level', fontsize=7)
plt.legend(loc='upper right', fontsize=7, title='salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/tXk04LJ/41.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %%
# Your Code is Here

sorted = salaries.groupby(['education_level']).salary.value_counts()
education_level = salaries.groupby(['education_level']).size()
percentages = sorted/education_level
percentages
# Out:
# education_level     salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# dtype: float64

# %% [raw]
# Desired Output:
#
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
# Your Code is Here

# high_lvl = percentages.loc['high_level_grade']
# low_lvl = percentages.loc['low_level_grade']
# medium_lvl = percentages.loc['medium_level_grade']

fig, ax = plt.subplots(nrows=1,ncols=3,figsize=(18,6))
colors = ['pink','lightskyblue']
labels = [percentages.high_level_grade.index[0], percentages.high_level_grade.index[1]]
# explode_list = [0.0,0.1]

ax[0].pie(x=percentages.high_level_grade,
            #  hue =percentages.index['education_level'],
             data=percentages,  
             colors=colors,
             autopct='%1.1f%%',
             labels=labels,
            #  explode=explode_list,
             shadow=False)
ax[1].pie(x=percentages.low_level_grade,
            #  hue =percentages.index['education_level'],
             data=percentages,  
             colors=colors,
             autopct='%1.1f%%',
             labels=labels,
            #  explode=explode_list,
             shadow=False)

ax[2].pie(x=percentages.medium_level_grade,
            #  hue =percentages.index['education_level'],
             data=percentages,  
             colors=colors,
             autopct='%1.1f%%',
             labels=labels,
            #  explode=explode_list,
             shadow=False)


ax[0].set_title(percentages.index[0][0])
ax[1].set_title(percentages.index[2][0])
ax[2].set_title(percentages.index[4][0])



for ax in ax:
    ax.set_ylabel('salary')

# plt.xticks(rotation=0, fontsize=7)
# plt.yticks(yticks,rotation=0, fontsize=7)
# plt.xlabel('Education Level', fontsize=7)
# ax[0].set_ylabel('salary', fontsize=7)
# plt.legend(loc='upper right', fontsize=7, title='salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9W6kXc6/42.png)

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby(['salary', 'education_level']).size().sort_values(ascending=False)
# Out:
# salary  education_level
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# dtype: int64

# %% [raw]
# Desired Output:
#
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 16000
steps = 9
yticks = np.linspace(start, end, steps)
sns.countplot(x='salary', 
              hue='education_level', 
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Salary', fontsize=7)
plt.legend(loc='upper right', fontsize=7, title='Education Summary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/K9xLxvF/43.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

sorted = salaries.groupby(['salary']).education_level.value_counts()
salary = salaries.groupby(['salary']).size()
percentages = sorted/salary
# percentages = percentages.sort_index(ascending=True)
percentages
# Out:
# salary  education_level
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# dtype: float64

# %% [raw]
# Desired Output:
#
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
for i in [0,0]:
    print(i)
# Out:
# 0
# 0

# %%
percentages[3:6]
# Out:
# salary  education_level
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# dtype: float64

# %%
# Your Code is Here

plt.figure(figsize = (18, 6))
index = 1
for i in [0,3]:
    plt.subplot(1, 2, index)
    percentages[i:i+3].plot.pie(subplots=True, autopct='%1.2f%%',
                        colors=["pink", 'lightskyblue', 'lightgreen'])
    index+=1


# ax[0].set_title(percentages.salary[0][0])
# ax[1].set_title(percentages.salary[2][0])

plt.show()

# %%
percentages
# Out:
# salary  education_level
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# dtype: float64

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/42pnNPc/44.png)

# %%
# Your Code is Here
percentages = percentages.sort_index(ascending=True)

percentages = percentages.reset_index()
percentages.rename({0:'percentages'}, axis =1, inplace =True)

# %%
percentages
# Out:
#   salary     education_level  percentages
# 0  <=50K    high_level_grade        0.168
# 1  <=50K     low_level_grade        0.162
# 2  <=50K  medium_level_grade        0.670
# 3   >50K    high_level_grade        0.499
# 4   >50K     low_level_grade        0.031
# 5   >50K  medium_level_grade        0.470

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/jHYrhz8/45.png)

# %%
# percentages.education_level.values[]

# %%
[i for i in percentages.education_level.apply(lambda x:x.split('_')[0])]
# Out:
# ['high', 'low', 'medium', 'high', 'low', 'medium']

# %%
percentages.percentages[1]
# Out:
# 0.16211839015304882

# %%
# Your Code is Here


fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,6))
index=1
index_2 = 0


for i in [0,3]:
    plt.subplot(1, 2, index)
    percentages.percentages[i:i+3].plot.pie(subplots=True,autopct='%1.2f%%', 
                                            labels=[i for i in percentages.education_level.apply(lambda x:x.split('_')[0])], 
                                            colors=["pink", 'lightskyblue', 'lightgreen'])
    plt.title(percentages.salary.head(i+1).iloc[i])
    
    index+=1
    


plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5BnYV6h/46.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result : There is a strong correlation between the salary level and education level. As it can be seen, the higher education level people are the majority of higher salary range.**

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

salaries.marital_status.value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %% [raw]
# Desired Output:
#
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
# Your Code is Here

salaries.relationship.value_counts()
# Out:
# Husband           13187
# Not-in-family      8292
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %% [raw]
# Desired Output:
#
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill missing values with "Unknown" in the column of "relationship"

# Your Code is Here

salaries.relationship.fillna('Unkown', inplace=True)

# %%
# Your Code is Here

salaries.groupby(['relationship', 'marital_status']).size()
# Out:
# relationship    marital_status
# Husband         Married-AF-spouse            9
#                 Married-civ-spouse       13178
# Not-in-family   Divorced                  2403
#                 Married-civ-spouse          17
#                 Married-spouse-absent      211
#                 Never-married             4694
#                 Separated                  420
#                 Widowed                    547
# Other-relative  Divorced                   110
#                 Married-AF-spouse            1
#                 Married-civ-spouse         124
#                 Married-spouse-absent       32
#                 Never-married              611
#                 Separated                   55
#                 Widowed                     48
# Unkown          Divorced                   328
#                 Married-AF-spouse            1
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Never-married             4481
#                 Separated                   99
#                 Widowed                     15
# Unmarried       Divorced                  1600
#                 Married-spouse-absent      130
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
# Wife            Married-AF-spouse           12
#                 Married-civ-spouse        1556
# dtype: int64

# %% [raw]
# Desired Output:
#
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: marital_status, dtype: int64

# %% [markdown]
# **Assessment :** ........

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 14000
steps = 9
yticks = np.linspace(start, end, steps)
sns.countplot(x='marital_status', 
              #hue='education_level', 
              data=salaries)
plt.xticks(rotation=45, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Marital Status', fontsize=7)
# plt.legend(loc='upper right', fontsize=7, title='Education Summary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/1RNHVvj/47.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby(['marital_status', 'salary']).size()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# dtype: int64

# %% [raw]
# Desired Output:
#
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 10000
steps = 9
yticks = np.linspace(start, end, steps)
sns.countplot(x='marital_status', 
              hue='salary', 
              data=salaries)
plt.xticks(rotation=45, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Marital Status', fontsize=7)
plt.legend(loc='upper right', fontsize=7, title='Salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qjNhW9h/48.png)

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
salaries.marital_status.value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
# Your Code is Here

salaries['marital_status'].apply(mapping_marital_status).value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %% [raw]
# Desired Output:
#
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"

# Your Code is Here

salaries['married'] = salaries['marital_status'].apply(mapping_marital_status)
salaries.married.value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: married, dtype: int64

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 16000
steps = 9
yticks = np.linspace(start, end, steps)
sns.countplot(x='married', 
              #hue='salary', 
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Marital Status', fontsize=7)
# plt.legend(loc='upper right', fontsize=7, title='Marital Status Summary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/wRjj6Bx/49.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby(['married','salary']).size()
# Out:
# married    salary
# married    <=50K      8677
#            >50K       6734
# unmarried  <=50K     16021
#            >50K       1105
# dtype: int64

# %% [raw]
# Desired Output:
#
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 16000
steps = 9
yticks = np.linspace(start, end, steps)
sns.countplot(x='married', 
              hue='salary', 
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Marital Status', fontsize=7)
plt.legend(loc='upper right', fontsize=7, title='Salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0JtYnFb/50.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %%
# Your Code is Here

sorted_1 = salaries.groupby(['married']).salary.value_counts()
marriage = salaries.groupby(['married']).size()
percentages_1 = sorted_1/marriage
# percentages = percentages.sort_index(ascending=True)
percentages_1
# Out:
# married    salary
# married    <=50K    0.563
#            >50K     0.437
# unmarried  <=50K    0.935
#            >50K     0.065
# dtype: float64

# %% [raw]
# Desired Output:
#
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
percentages_1.index
# Out:
# MultiIndex([(  'married', '<=50K'),
#             (  'married',  '>50K'),
#             ('unmarried', '<=50K'),
#             ('unmarried',  '>50K')],
#            names=['married', 'salary'])

# %%
percentages_1.index.get_level_values(1).unique().to_list()[1]
# Out:
# '>50K'

# %%
percentages_1.head(3).iloc[2]
# Out:
# 0.9354782202499125

# %%
# Your Code is Here

plt.figure(figsize = (18, 6))
index = 1
for i in [0,2]:
    plt.subplot(1, 2, index)
    percentages_1[i:i+2].plot.pie(subplots=True, 
                                autopct='%1.2f%%', 
                                labels=percentages_1.index.get_level_values(1).unique().to_list(),
                                colors=["pink", 'lightskyblue', 'lightgreen'])
    plt.title(percentages_1.index.get_level_values(0).unique().to_list()[index-1])
    index+=1

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TYxT5Zz/51.png)

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %%
salaries.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary', 'education_level', 'married'],
#       dtype='object')

# %%
# Your Code is Here

salaries.groupby('salary').married.value_counts()
# Out:
# salary  married
# <=50K   unmarried    16021
#         married       8677
# >50K    married       6734
#         unmarried     1105
# Name: married, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 16000
steps = 9
yticks = np.linspace(start, end, steps)
sns.countplot(x='salary', 
              hue='married', 
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Marital Status', fontsize=7)
plt.legend(loc='upper right', fontsize=7, title='Salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/YWjjsZP/52.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

sorted_2 = salaries.groupby(['salary'])['married'].value_counts()
marriage = salaries.groupby(['salary']).size()
percentages_2 = sorted_2/marriage
# percentages = percentages.sort_index(ascending=True)
percentages_2
# Out:
# salary  married
# <=50K   unmarried   0.649
#         married     0.351
# >50K    married     0.859
#         unmarried   0.141
# dtype: float64

# %% [raw]
# Desired Output:
#
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
# Your Code is Here
df_per = percentages_2.reset_index().sort_values(by=['salary', 'married'])
df_per.rename({0:'percentages'}, axis =1, inplace =True)
df_per
# Out:
#   salary    married  percentages
# 1  <=50K    married        0.351
# 0  <=50K  unmarried        0.649
# 2   >50K    married        0.859
# 3   >50K  unmarried        0.141

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Swb4rb7/v53.png)

# %%
# Your Code is Here


plt.figure(figsize = (12, 5))
index = 1
for i in [0,2]:
    plt.subplot(1, 2, index)
    df_per.percentages[i:i+2].plot.pie(subplots=True, 
                                autopct='%1.2f%%', 
                                labels=percentages_1.index.get_level_values(0).unique().to_list(),
                                colors=["pink", 'lightskyblue', 'lightgreen'])
    plt.title(percentages_2.index.get_level_values(0).unique().to_list()[index-1])
    index+=1

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cJxmqwG/54.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %%
salaries.groupby('salary').age.describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# **Result :** Even thought the married people might seem like they are making a high salary, the age group of the lower salary range shows that they are much younger than the higher level salary people. So that might not be the best thing to consider when it comes to income levels.

# %% [markdown]
# ## workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

salaries.workclass.value_counts(ascending=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %% [raw]
# Desired Output:
#
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here

# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 20000
steps = 5
yticks = np.linspace(start, end, steps)
sns.countplot(x='workclass', 
              #hue='education_level', 
              data=salaries)
plt.xticks(rotation=90, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Work Class', fontsize=7)
# plt.legend(loc='upper right', fontsize=7, title='Education Summary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/NmKTp84/55.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unkown"

# Your Code is Here

salaries['workclass'] = salaries['workclass'].replace('?', 'Unkown')
salaries[salaries.workclass == 'Unkown']
# Out:
#        age workclass  fnlwgt     education  education_num  \
# 27      54    Unkown  180211  Some-college         10.000
# 61      32    Unkown  293936       7th-8th          4.000
# 69      25    Unkown  200681  Some-college         10.000
# 77      67    Unkown  212759          10th          6.000
# 106     17    Unkown  304873          10th          6.000
# ...    ...       ...     ...           ...            ...
# 32530   35    Unkown  320084     Bachelors         13.000
# 32531   30    Unkown   33811     Bachelors         13.000
# 32539   71    Unkown  287372     Doctorate            NaN
# 32541   41    Unkown  202822       HS-grad          9.000
# 32542   72    Unkown  129912       HS-grad          9.000
#
#               marital_status occupation   relationship                race  \
# 27        Married-civ-spouse          ?        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent          ?  Not-in-family               White
# 69             Never-married          ?         Unkown               White
# 77        Married-civ-spouse          ?        Husband               White
# 106            Never-married          ?         Unkown               White
# ...                      ...        ...            ...                 ...
# 32530     Married-civ-spouse          ?           Wife               White
# 32531          Never-married          ?  Not-in-family  Asian-Pac-Islander
# 32539     Married-civ-spouse          ?        Husband               White
# 32541              Separated          ?  Not-in-family               Black
# 32542     Married-civ-spouse          ?        Husband               White
#
#           sex  capital_gain  capital_loss  hours_per_week native_country  \
# 27       Male             0             0              60          South
# 61       Male             0             0              40              ?
# 69       Male             0             0              40  United-States
# 77       Male             0             0               2  United-States
# 106    Female         34095             0              32  United-States
# ...       ...           ...           ...             ...            ...
# 32530  Female             0             0              55  United-States
# 32531  Female             0             0              99  United-States
# 32539    Male             0             0              10  United-States
# 32541  Female             0             0              32  United-States
# 32542    Male             0             0              25  United-States
#
#       salary     education_level    married
# 27      >50K  medium_level_grade    married
# 61     <=50K     low_level_grade    married
# 69     <=50K  medium_level_grade  unmarried
# 77     <=50K     low_level_grade    married
# 106    <=50K     low_level_grade  unmarried
# ...      ...                 ...        ...
# 32530   >50K    high_level_grade    married
# 32531  <=50K    high_level_grade  unmarried
# 32539   >50K    high_level_grade    married
# 32541  <=50K  medium_level_grade  unmarried
# 32542  <=50K  medium_level_grade    married
#
# [1836 rows x 17 columns]

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
# Your Code is Here
salaries.groupby(['workclass']).salary.value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unkown            <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 17500
steps = 9
yticks = np.linspace(start, end, steps)
sns.countplot(x='workclass', 
              hue='salary', 
              data=salaries)
plt.xticks(rotation=90, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Work Class', fontsize=7)
plt.legend(loc='upper left', fontsize=7, title='Salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/bPnNvsn/56.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
# Your Code is Here

workclass = salaries.groupby(['workclass']).salary.value_counts()/salaries.groupby(['workclass']).size()
workclass
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unkown            <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# dtype: float64

# %% [raw]
# Desired Output:
#
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
# Your Code is Here

workclass = workclass.reset_index()

# %%
workclass.rename(columns={0:"percentage"}, inplace=True)
workclass
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13            Unkown  <=50K       0.896
# 14            Unkown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/8YvM14M/57.png)

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 1
steps = 6
yticks = np.linspace(start, end, steps)
sns.barplot(x='workclass', 
              y='percentage',
              hue='salary', 
              data=workclass)


for i in ax.patches:
    ax.annotate('{:.2f}'.format(i.get_height()), (i.get_x(), i.get_height()), fontsize=7 )
    
plt.xticks(rotation=90, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Percentage', fontsize=7)
plt.xlabel('Work Class', fontsize=7)
plt.legend(loc='upper left', fontsize=7, title='Salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/NFN5q04/58.png)

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby('salary').workclass.value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unkown               1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unkown                191
# Name: workclass, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
# Your Code is Here


fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 17500
steps = 6
yticks = np.linspace(start, end, steps)
sns.countplot(x='salary', 
              #y='workclass',
              hue='workclass', 
              data=salaries)


# for i in ax.patches:
#     ax.annotate('{:.2f}'.format(i.get_height()), (i.get_x(), i.get_height()), fontsize=7 )
    
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Salary', fontsize=7)
plt.legend(loc='upper center', fontsize=7, title='Workclass', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/98V8zkN/59.png)

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

sp = salaries.groupby('salary').workclass.value_counts()/salaries.groupby('salary').size()
sp = sp.reset_index()

# %%
sp = sp.sort_values(by=['salary', 'workclass'])

# %% [raw]
# Desired Output:
#
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
# Your Code is Here
sp.rename(columns={0:'percentage'}, inplace=True)
sp
# Out:
#    salary         workclass  percentage
# 5   <=50K       Federal-gov       0.024
# 3   <=50K         Local-gov       0.060
# 8   <=50K      Never-worked       0.000
# 0   <=50K           Private       0.717
# 6   <=50K      Self-emp-inc       0.020
# 1   <=50K  Self-emp-not-inc       0.074
# 4   <=50K         State-gov       0.038
# 2   <=50K            Unkown       0.067
# 7   <=50K       Without-pay       0.001
# 13   >50K       Federal-gov       0.047
# 12   >50K         Local-gov       0.079
# 9    >50K           Private       0.633
# 11   >50K      Self-emp-inc       0.079
# 10   >50K  Self-emp-not-inc       0.092
# 14   >50K         State-gov       0.045
# 15   >50K            Unkown       0.024

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/QcdnXpk/60.png)

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(10,4))
start = 0
end = 0.7
steps = 6
yticks = np.linspace(start, end, steps)
sns.barplot(x='salary', 
              y='percentage',
              hue='workclass', 
              data=sp)


for i in ax.patches:
    ax.annotate('{:.3f}'.format(i.get_height()), ((i.get_x()+i.get_width())-0.08, i.get_height()+0.01), fontsize=7 )
    
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Salary', fontsize=7)
plt.legend(loc='upper left', fontsize=7, title='Workclass', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Kz5BDBj/61.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** According to this data set, it is safe to say that almost in all of the sectors, people who are paid a high salary is lower than the people who get paid a low salary. However, the self-employed people are the only exepciton of this. It is safe to say that private sector and self-employed people are likely to earn a higher salary than the rest of the groups.

# %% [markdown]
# ## occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

salaries.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %% [raw]
# Desired Output:
#
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 4000
steps = 5
yticks = np.linspace(start, end, steps)
sns.countplot(x='occupation', 
              #hue='education_level', 
              data=salaries)
plt.xticks(rotation=90, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Occupation', fontsize=7)
# plt.legend(loc='upper right', fontsize=7, title='Education Summary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/F3qqLjS/62.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

salaries['occupation'] = salaries['occupation'].replace('?', 'Unkown')
salaries[salaries.workclass == 'Unkown']
# Out:
#        age workclass  fnlwgt     education  education_num  \
# 27      54    Unkown  180211  Some-college         10.000
# 61      32    Unkown  293936       7th-8th          4.000
# 69      25    Unkown  200681  Some-college         10.000
# 77      67    Unkown  212759          10th          6.000
# 106     17    Unkown  304873          10th          6.000
# ...    ...       ...     ...           ...            ...
# 32530   35    Unkown  320084     Bachelors         13.000
# 32531   30    Unkown   33811     Bachelors         13.000
# 32539   71    Unkown  287372     Doctorate            NaN
# 32541   41    Unkown  202822       HS-grad          9.000
# 32542   72    Unkown  129912       HS-grad          9.000
#
#               marital_status occupation   relationship                race  \
# 27        Married-civ-spouse     Unkown        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent     Unkown  Not-in-family               White
# 69             Never-married     Unkown         Unkown               White
# 77        Married-civ-spouse     Unkown        Husband               White
# 106            Never-married     Unkown         Unkown               White
# ...                      ...        ...            ...                 ...
# 32530     Married-civ-spouse     Unkown           Wife               White
# 32531          Never-married     Unkown  Not-in-family  Asian-Pac-Islander
# 32539     Married-civ-spouse     Unkown        Husband               White
# 32541              Separated     Unkown  Not-in-family               Black
# 32542     Married-civ-spouse     Unkown        Husband               White
#
#           sex  capital_gain  capital_loss  hours_per_week native_country  \
# 27       Male             0             0              60          South
# 61       Male             0             0              40              ?
# 69       Male             0             0              40  United-States
# 77       Male             0             0               2  United-States
# 106    Female         34095             0              32  United-States
# ...       ...           ...           ...             ...            ...
# 32530  Female             0             0              55  United-States
# 32531  Female             0             0              99  United-States
# 32539    Male             0             0              10  United-States
# 32541  Female             0             0              32  United-States
# 32542    Male             0             0              25  United-States
#
#       salary     education_level    married
# 27      >50K  medium_level_grade    married
# 61     <=50K     low_level_grade    married
# 69     <=50K  medium_level_grade  unmarried
# 77     <=50K     low_level_grade    married
# 106    <=50K     low_level_grade  unmarried
# ...      ...                 ...        ...
# 32530   >50K    high_level_grade    married
# 32531  <=50K    high_level_grade  unmarried
# 32539   >50K    high_level_grade    married
# 32541  <=50K  medium_level_grade  unmarried
# 32542  <=50K  medium_level_grade    married
#
# [1836 rows x 17 columns]

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby(['occupation']).salary.value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# Unkown             <=50K     1652
#                    >50K       191
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# Unknown            <=50K     1652
#                    >50K       191
# Name: salary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(5.5,4))
start = 0
end = 3000
steps = 9
yticks = np.linspace(start, end, steps)
sns.countplot(x='occupation', 
              hue='salary', 
              data=salaries)
plt.xticks(rotation=90, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Work Class', fontsize=7)
plt.legend(loc='upper right', fontsize=7, title='Salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/RhkhQCW/63.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %%
# Your Code is Here

occupation = salaries.groupby(['occupation']).salary.value_counts()/salaries.groupby(['occupation']).size()
occupation = occupation.reset_index()

# %% [raw]
# Desired Output:
#
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
#                    >50K     0.200
# Unknown            <=50K    0.896
#                    >50K     0.104
# Name: salary, dtype: float64

# %%
# Your Code is Here

occupation.rename(columns={0:"percentage"}, inplace=True)
occupation
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# 22              Sales  <=50K       0.731
# 23              Sales   >50K       0.269
# 24       Tech-support  <=50K       0.695
# 25       Tech-support   >50K       0.305
# 26   Transport-moving  <=50K       0.800
# 27   Transport-moving   >50K       0.200
# 28             Unkown  <=50K       0.896
# 29             Unkown   >50K       0.104

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mb7JS3n/64.png)

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(10,5))
start = 0
end = 1
steps = 6
yticks = np.linspace(start, end, steps)
sns.barplot(x='occupation', 
              y='percentage',
              hue='salary', 
              data=occupation)


for i in ax.patches:
    ax.annotate('{:.2f}'.format(i.get_height()), (i.get_x(), i.get_height()), fontsize=7 )
    
plt.xticks(rotation=90, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Percentage', fontsize=7)
plt.xlabel('Work Class', fontsize=7)
plt.legend(loc='upper left', fontsize=7, title='Salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/sW2b8wL/65.png)

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby('salary').occupation.value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unkown               1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unkown                191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: occupation, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: occupation, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(6,4))
start = 0
end = 3000
steps = 6
yticks = np.linspace(start, end, steps)
sns.countplot(x='salary', 
              #y='workclass',
              hue='occupation', 
              data=salaries)


# for i in ax.patches:
#     ax.annotate('{:.2f}'.format(i.get_height()), (i.get_x(), i.get_height()), fontsize=7 )
    
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Salary', fontsize=7)
plt.legend(loc='upper right', fontsize=7, title='Workclass', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cvHS3FH/66.png)

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

occ = salaries.groupby('salary').occupation.value_counts()/salaries.groupby('salary').size()
occ = occ.reset_index()

# %%
occ
# Out:
#    salary         occupation     0
# 0   <=50K       Adm-clerical 0.132
# 1   <=50K       Craft-repair 0.128
# 2   <=50K      Other-service 0.128
# 3   <=50K              Sales 0.108
# 4   <=50K     Prof-specialty 0.092
# 5   <=50K    Exec-managerial 0.085
# 6   <=50K  Machine-op-inspct 0.071
# 7   <=50K             Unkown 0.067
# 8   <=50K  Handlers-cleaners 0.052
# 9   <=50K   Transport-moving 0.052
# 10  <=50K    Farming-fishing 0.036
# 11  <=50K       Tech-support 0.026
# 12  <=50K    Protective-serv 0.018
# 13  <=50K    Priv-house-serv 0.006
# 14  <=50K       Armed-Forces 0.000
# 15   >50K    Exec-managerial 0.251
# 16   >50K     Prof-specialty 0.237
# 17   >50K              Sales 0.125
# 18   >50K       Craft-repair 0.119
# 19   >50K       Adm-clerical 0.065
# 20   >50K   Transport-moving 0.041
# 21   >50K       Tech-support 0.036
# 22   >50K  Machine-op-inspct 0.032
# 23   >50K    Protective-serv 0.027
# 24   >50K             Unkown 0.024
# 25   >50K      Other-service 0.017
# 26   >50K    Farming-fishing 0.015
# 27   >50K  Handlers-cleaners 0.011
# 28   >50K       Armed-Forces 0.000
# 29   >50K    Priv-house-serv 0.000

# %% [raw]
# Desired Output:
#
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
#         Handlers-cleaners   0.011
#         Armed-Forces        0.000
#         Priv-house-serv     0.000
# Name: occupation, dtype: float64

# %%
# Your Code is Here

occ.rename(columns={0:'percentage'}, inplace=True)
occ = occ.sort_values(by=['salary', 'occupation'])
occ
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 14  <=50K       Armed-Forces       0.000
# 1   <=50K       Craft-repair       0.128
# 5   <=50K    Exec-managerial       0.085
# 10  <=50K    Farming-fishing       0.036
# 8   <=50K  Handlers-cleaners       0.052
# 6   <=50K  Machine-op-inspct       0.071
# 2   <=50K      Other-service       0.128
# 13  <=50K    Priv-house-serv       0.006
# 4   <=50K     Prof-specialty       0.092
# 12  <=50K    Protective-serv       0.018
# 3   <=50K              Sales       0.108
# 11  <=50K       Tech-support       0.026
# 9   <=50K   Transport-moving       0.052
# 7   <=50K             Unkown       0.067
# 19   >50K       Adm-clerical       0.065
# 28   >50K       Armed-Forces       0.000
# 18   >50K       Craft-repair       0.119
# 15   >50K    Exec-managerial       0.251
# 26   >50K    Farming-fishing       0.015
# 27   >50K  Handlers-cleaners       0.011
# 22   >50K  Machine-op-inspct       0.032
# 25   >50K      Other-service       0.017
# 29   >50K    Priv-house-serv       0.000
# 16   >50K     Prof-specialty       0.237
# 23   >50K    Protective-serv       0.027
# 17   >50K              Sales       0.125
# 21   >50K       Tech-support       0.036
# 20   >50K   Transport-moving       0.041
# 24   >50K             Unkown       0.024

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7tK0PqX/67.png)

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(12,5))
start = 0
end = 0.25
steps = 6
yticks = np.linspace(start, end, steps)
sns.barplot(x='salary', 
              y='percentage',
              hue='occupation', 
              data=occ)


for i in ax.patches:
    ax.annotate('{:.3f}'.format(i.get_height()), (i.get_x(), i.get_height()), fontsize=7 )
    
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Percentage', fontsize=7)
plt.xlabel('Salary', fontsize=5)
plt.legend(loc='upper right', fontsize=7, title='Salary', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7brj34F/68.png)

# %%
it_people = salaries[(salaries['occupation'] == 'Tech-support')]
it_people.columns
sns.boxplot(y=it_people['age'], x=it_people['salary'])
# Out:
# <Axes: xlabel='salary', ylabel='age'>

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** When we look at this data set and the countplot provided, it is easy to say that the private sector and high education jobs are very likely to have a higher salary than any other sevtore. In retrospevtive, the sales jobs come in a much lower percentage for above 50k salaries than below 50k salary range. It is safe to say that sales people are not likely to make too much money as expected.
# Also we can say that the tech jobs will provide a higher salary than other jobs other than high education or managerial services. Also when we look at the boxplot above, we can say that there is a high chance that an IT career will turn into a high paying job over time.

# %% [markdown]
# ## race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here
salaries['race'].value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %% [raw]
# Desired Output:
#
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
# Your Code is Here
fig, ax = plt.subplots(figsize=(6,4)); start, end, steps = 0, 25000, 7
yticks = np.linspace(start, end, steps)
sns.countplot(x='race',
              #hue='',
              data=salaries)
plt.xticks(rotation=45, fontsize=7)
plt.yticks(yticks, rotation=0,fontsize=7)

plt.xlabel('Race', fontsize=7)
plt.ylabel('Count', fontsize=7)

#plt.legend(loc='upper right', fontsize=7, title='Salary', title_fontsize=7)

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/LdKct3G/69.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by races and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby('race').salary.value_counts(ascending=False)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(6,4)); start, end, steps = 0, 18000, 7
yticks = np.linspace(start, end, steps)
sns.countplot(x='race',
              hue='salary',
              data=salaries)
plt.xticks(rotation=45, fontsize=7)
plt.yticks(yticks, rotation=0,fontsize=7)

plt.xlabel('Race', fontsize=7)
plt.ylabel('Count', fontsize=7)

plt.legend(loc='upper right', fontsize=7, title='Salary', title_fontsize=7)

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Qb4n8Y5/70.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %%
# Your Code is Here

occupation = ((salaries.groupby(['race']).salary.value_counts() / salaries.groupby(['race']).size()).reset_index()).rename(columns={0:'percentage'})
occupation
# Out:
#                  race salary  percentage
# 0  Amer-Indian-Eskimo  <=50K       0.884
# 1  Amer-Indian-Eskimo   >50K       0.116
# 2  Asian-Pac-Islander  <=50K       0.734
# 3  Asian-Pac-Islander   >50K       0.266
# 4               Black  <=50K       0.876
# 5               Black   >50K       0.124
# 6               Other  <=50K       0.908
# 7               Other   >50K       0.092
# 8               White  <=50K       0.744
# 9               White   >50K       0.256

# %% [raw]
# Desired Output:
#
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
occupation.index.get_level_values(0).unique()
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
occupation.salary[1]
# Out:
# '>50K'

# %%
# Your Code is Here
plt.figure(figsize=(18,12))
index=1



for i in [0,2,4,6,8]:
    plt.subplot(2,3,index)
    
    occupation.percentage[i:i+2].plot.pie(subplots=True,
                                           autopct='%2.2f',
                                           colors=['pink','lightskyblue','lightgreen'],
                                           labels=occupation.salary[i:i+2],
                                           textprops={'fontsize':12})

    plt.ylabel('Salary', fontsize=7)
    plt.title(occupation.race[i])

    index+=1

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xsJWXp4/71.png)

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby('salary').race.value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
# Your Code is Here


fig, ax = plt.subplots(figsize=(6,4)); start, end, steps = 0, 20000, 7
yticks = np.linspace(start, end, steps)

sns.countplot(x='salary', 
              #y='workclass',
              hue='race', 
              data=salaries)


# for i in ax.patches:
#     ax.annotate('{:.2f}'.format(i.get_height()), (i.get_x(), i.get_height()), fontsize=7 )
    
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Count', fontsize=7)
plt.xlabel('Salary', fontsize=7)
plt.legend(loc='upper right', fontsize=7, title='Workclass', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/RBpPR38/72.png)

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here
race = ((salaries.groupby(['salary']).race.value_counts() / salaries.groupby(['salary']).size()).reset_index()).rename(columns={0:'percentage'}).sort_values(by=['salary', 'race'])

# %% [raw]
# Desired Output:
#
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
# Your Code is Here

race
# Out:
#   salary                race  percentage
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 2  <=50K  Asian-Pac-Islander       0.031
# 1  <=50K               Black       0.111
# 4  <=50K               Other       0.010
# 0  <=50K               White       0.837
# 8   >50K  Amer-Indian-Eskimo       0.005
# 7   >50K  Asian-Pac-Islander       0.035
# 6   >50K               Black       0.049
# 9   >50K               Other       0.003
# 5   >50K               White       0.908

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Xy9sYCY/73.png)

# %%
# Your Code is Here


fig, ax = plt.subplots(figsize=(10,6)); start, end, steps = 0, 0.8, 4
yticks = np.linspace(start, end, steps)
sns.barplot(x='salary', 
              y='percentage',
              hue='race', 
              data=race)


for i in ax.patches:
    ax.annotate('{:.3f}'.format(i.get_height()), ((i.get_x()+i.get_width())-0.1, i.get_height()+0.01), fontsize=7)
    
plt.xticks(rotation=00, fontsize=7)
plt.yticks(yticks,rotation=0, fontsize=7)
plt.ylabel('Percentage', fontsize=7)
plt.xlabel('Work Class', fontsize=7)
plt.legend(loc='upper left', fontsize=7, title='Work Class', title_fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/X8kf9NZ/74.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** It is hard to draw a comprehesive conclusion from this data set. We need to look further into the age groups and occupations before being sure that there is general pattern. However we can again say that the population is mainly white and they have a higher chance of finding a job with a higher pay. The black people follwo them with a very silar distribution. However, their under paid group is smaller than the white people's in respect to gender based comparasion.

# %% [markdown]
# ## gender

# %% [markdown]
# **Check the count of person in each gender and visualize it with countplot**

# %%
# Your Code is Here
salaries.sex.value_counts()
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
salaries.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary', 'education_level', 'married'],
#       dtype='object')

# %% [raw]
# Desired Output:
#
# Male      21775
# Female    10762
# Name: gender, dtype: int64

# %%
# Your Code is Here
fig, ax = plt.subplots(figsize=(6,4)); start, end, steps = 0, 20000, 7
yticks = np.linspace(start, end, steps)
sns.countplot(x='sex',
              #hue='',
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks, rotation=0,fontsize=7)

plt.xlabel('Race', fontsize=7)
plt.ylabel('Count', fontsize=7)

#plt.legend(loc='upper right', fontsize=7, title='Salary', title_fontsize=7)

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/GVTRbrb/75.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by gender and visualize it with countplot**

# %%
# Your Code is Here
salaries.groupby('sex').salary.value_counts()
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# gender  salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(6,4)); start, end, steps = 0, 14000, 7
yticks = np.linspace(start, end, steps)
sns.countplot(x='sex',
              hue='salary',
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks, rotation=0,fontsize=7)

plt.xlabel('Race', fontsize=7)
plt.ylabel('Count', fontsize=7)

plt.legend(loc='upper right', fontsize=7, title='Salary', title_fontsize=7)

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Nr8HRPk/76.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot**

# %%
# Your Code is Here
sex = ((salaries.groupby(['sex']).salary.value_counts() / salaries.groupby(['sex']).size()))

sex
# Out:
# sex     salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# dtype: float64

# %% [raw]
# Desired Output:
#
# gender  salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
sex.index.get_level_values(1)[0:2]
# Out:
# Index(['<=50K', '>50K'], dtype='object', name='salary')

# %%
# Your Code is Here
sex

plt.figure(figsize=(10,6))
index=1



for i in [0,2]:
    plt.subplot(1,2,index)
    
    sex[i:i+2].plot.pie(subplots=True,
                                           autopct='%2.2f',
                                           colors=['pink','lightskyblue','lightgreen'],
                                           labels=sex.index.get_level_values(1)[i:i+2],
                                           textprops={'fontsize':7})

    plt.ylabel('Salary', fontsize=7)
    plt.title(sex.index.get_level_values(0)[i])

    index+=1

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/nrHj2jk/77.png)

# %% [markdown]
# **Check the count of person in each gender by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby('salary').sex.value_counts()
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: gender, dtype: int64

# %%
# Your Code is Here
fig, ax = plt.subplots(figsize=(6,4)); start, end, steps = 0, 14000, 7
yticks = np.linspace(start, end, steps)
sns.countplot(x='salary',
              hue='sex',
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks, rotation=0,fontsize=7)

plt.xlabel('Race', fontsize=7)
plt.ylabel('Count', fontsize=7)

plt.legend(loc='upper right', fontsize=7, title='Gender', title_fontsize=7)

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9sfsw11/78.png)

# %% [markdown]
# **Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot**

# %%
# Your Code is Here


(salaries.groupby('salary').sex.value_counts()/salaries.groupby('salary').size()).index
# Out:
# MultiIndex([('<=50K',   'Male'),
#             ('<=50K', 'Female'),
#             ( '>50K',   'Male'),
#             ( '>50K', 'Female')],
#            names=['salary', 'sex'])

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: gender, dtype: float64

# %%
# Your Code is Here
plt.figure(figsize = (18, 6))
index = 1
for i in [0,2]:
    plt.subplot(1,2,index)
    (salaries.groupby('salary').sex.value_counts()/salaries.groupby('salary').size())[i:i+2].plot.pie(
                        subplots=True,
                        autopct='%2.2f',
                        colors=['pink','lightskyblue','lightgreen'],
                        labels=(salaries.groupby('salary').sex.value_counts()/salaries.groupby('salary').size()).index.get_level_values(1)[i:i+2],
                        textprops={'fontsize':12})

    plt.ylabel('Salary', fontsize=7)
    plt.title((salaries.groupby('salary').sex.value_counts()/salaries.groupby('salary').size()).index.get_level_values(0)[i])

    index+=1

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0DzhNgG/79.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ..............

# %% [markdown]
# ## native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby('native_country').size()
# Out:
# native_country
# ?                               582
# Cambodia                         19
# Canada                          121
# China                            75
# Columbia                         59
# Cuba                             95
# Dominican-Republic               70
# Ecuador                          28
# El-Salvador                     106
# England                          90
# France                           29
# Germany                         137
# Greece                           29
# Guatemala                        62
# Haiti                            44
# Holand-Netherlands                1
# Honduras                         13
# Hong                             20
# Hungary                          13
# India                           100
# Iran                             43
# Ireland                          24
# Italy                            73
# Jamaica                          81
# Japan                            62
# Laos                             18
# Mexico                          639
# Nicaragua                        34
# Outlying-US(Guam-USVI-etc)       14
# Peru                             31
# Philippines                     198
# Poland                           60
# Portugal                         37
# Puerto-Rico                     114
# Scotland                         12
# South                            80
# Taiwan                           51
# Thailand                         18
# Trinadad&Tobago                  19
# United-States                 29153
# Vietnam                          67
# Yugoslavia                       16
# dtype: int64

# %% [raw]
# Desired Output:
#
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64

# %%
# Your Code is Here
fig, ax = plt.subplots(figsize=(12,5)); start, end, steps = 0, 30000, 7
yticks = np.linspace(start, end, steps)
sns.countplot(x='native_country',
              #hue='salary',
              data=salaries)
plt.xticks(rotation=90, fontsize=7)
plt.yticks(yticks, rotation=0,fontsize=7)

plt.xlabel('Native Country', fontsize=7)
plt.ylabel('Count', fontsize=7)

# plt.legend(loc='upper right', fontsize=7, title='Native Country', title_fontsize=7)

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x3TNT7B/80.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

salaries['native_country'] = salaries['native_country'].replace('?', 'Unkown')
salaries[salaries.native_country == 'Unkown']
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 14      40           Private  121772     Assoc-voc            NaN
# 38      31           Private   84154  Some-college            NaN
# 51      18           Private  226956       HS-grad          9.000
# 61      32            Unkown  293936       7th-8th          4.000
# 93      30           Private  117747       HS-grad          9.000
# ...    ...               ...     ...           ...            ...
# 32449   44      Self-emp-inc   71556       Masters         14.000
# 32469   58      Self-emp-inc  181974     Doctorate         16.000
# 32492   42  Self-emp-not-inc  217597       HS-grad          9.000
# 32510   39           Private  107302       HS-grad          9.000
# 32525   81            Unkown  120478     Assoc-voc         11.000
#
#               marital_status      occupation   relationship  \
# 14        Married-civ-spouse    Craft-repair        Husband
# 38        Married-civ-spouse           Sales        Husband
# 51             Never-married   Other-service         Unkown
# 61     Married-spouse-absent          Unkown  Not-in-family
# 93        Married-civ-spouse           Sales           Wife
# ...                      ...             ...            ...
# 32449     Married-civ-spouse           Sales        Husband
# 32469          Never-married  Prof-specialty  Not-in-family
# 32492               Divorced           Sales         Unkown
# 32510     Married-civ-spouse  Prof-specialty        Husband
# 32525               Divorced          Unkown      Unmarried
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 14     Asian-Pac-Islander    Male             0             0              40
# 38                  White    Male             0             0              38
# 51                  White  Female             0             0              30
# 61                  White    Male             0             0              40
# 93     Asian-Pac-Islander  Female             0          1573              35
# ...                   ...     ...           ...           ...             ...
# 32449               White    Male             0             0              50
# 32469               White  Female             0             0              99
# 32492               White    Male             0             0              50
# 32510               White    Male             0             0              45
# 32525               White  Female             0             0               1
#
#       native_country salary     education_level    married
# 14            Unkown   >50K  medium_level_grade    married
# 38            Unkown   >50K  medium_level_grade    married
# 51            Unkown  <=50K  medium_level_grade  unmarried
# 61            Unkown  <=50K     low_level_grade    married
# 93            Unkown  <=50K  medium_level_grade    married
# ...              ...    ...                 ...        ...
# 32449         Unkown   >50K    high_level_grade    married
# 32469         Unkown  <=50K    high_level_grade  unmarried
# 32492         Unkown  <=50K  medium_level_grade  unmarried
# 32510         Unkown   >50K  medium_level_grade    married
# 32525         Unkown  <=50K  medium_level_grade  unmarried
#
# [582 rows x 17 columns]

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
salaries.native_country.apply(mapping_native_country).value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
# Your Code is Here

salaries['native_country'].apply(mapping_native_country)
# Out:
# 0        Others
# 1        Others
# 2        Others
# 3        Others
# 4        Others
#           ...
# 32556    Others
# 32557    Others
# 32558    Others
# 32559    Others
# 32560    Others
# Name: native_country, Length: 32537, dtype: object

# %% [raw]
# Desired Output:
#
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"

# Your Code is Here

salaries['native_country_summary'] = salaries.native_country.apply(mapping_native_country) 
salaries.native_country_summary
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %% [raw]
# Desired Output:
#
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %%
# Your Code is Here
fig, ax = plt.subplots(figsize=(6,4)); start, end, steps = 0, 30000, 7
yticks = np.linspace(start, end, steps)
sns.countplot(x='native_country_summary',
              #hue='sex',
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks, rotation=0,fontsize=7)

plt.xlabel('Race', fontsize=7)
plt.ylabel('Count', fontsize=7)

plt.legend(loc='upper right', fontsize=7, title='Gender', title_fontsize=7)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/wwDhVGd/81.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot**

# %%
# Your Code is Here
salaries.groupby('native_country_summary').salary.value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(6,4)); start, end, steps = 0, 20000, 5
yticks = np.linspace(start, end, steps)
sns.countplot(x='native_country_summary',
              hue='salary',
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks, rotation=0,fontsize=7)

plt.xlabel('Native Country Summary', fontsize=7)
plt.ylabel('Count', fontsize=7)

plt.legend(loc='upper right', fontsize=7, title='Salary', title_fontsize=7)

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/SVnKp4k/82.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %%
# Your Code is Here

(salaries.groupby('native_country_summary').salary.value_counts()/salaries.groupby('native_country_summary').size()).index.get_level_values(0)
# Out:
# Index(['Others', 'Others', 'US', 'US'], dtype='object', name='native_country_summary')

# %% [raw]
# Desired Output:
#
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
# Your Code is Here
plt.figure(figsize = (13, 4))
index = 1
for i in [0,2]:
    plt.subplot(1,2,index)
    (salaries.groupby('native_country_summary').salary.value_counts()/salaries.groupby('native_country_summary').size())[i:i+2].plot.pie(
                        subplots=True,
                        autopct='%2.2f',
                        colors=['pink','lightskyblue','lightgreen'],
                        labels=(salaries.groupby('salary').sex.value_counts()/salaries.groupby('salary').size()).index.get_level_values(0)[i:i+2],
                        textprops={'fontsize':12})

    plt.ylabel('Salary', fontsize=7)
    plt.title((salaries.groupby('native_country_summary').salary.value_counts()/salaries.groupby('native_country_summary').size()).index.get_level_values(0)[i])

    index+=1

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4NQ5b1b/83.png)

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

salaries.groupby('salary').native_country_summary.value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(6,4)); start, end, steps = 0, 20000, 7
yticks = np.linspace(start, end, steps)
sns.countplot(x='salary',
              hue='native_country_summary',
              data=salaries)
plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks, rotation=0,fontsize=7)

plt.xlabel('Salary', fontsize=7)
plt.ylabel('Count', fontsize=7)

plt.legend(loc='upper right', fontsize=7, title='native_country_summary', title_fontsize=7)

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/c1gQfcg/84.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

(salaries.groupby('salary').native_country_summary.value_counts()/salaries.groupby('salary').size())
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# dtype: float64

# %% [raw]
# Desired Output:
#
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
# Your Code is Here

plt.figure(figsize = (13, 4))
index = 1
for i in [0,2]:
    plt.subplot(1,2,index)
    (salaries.groupby('salary').native_country_summary.value_counts()/salaries.groupby('salary').size())[i:i+2].plot.pie(
                        subplots=True,
                        autopct='%2.2f',
                        colors=['pink','lightskyblue','lightgreen'],
                        labels=(salaries.groupby('salary').native_country_summary.value_counts()/salaries.groupby('salary').size()).index.get_level_values(1)[i:i+2],
                        textprops={'fontsize':7})

    plt.ylabel('Salary', fontsize=7)
    plt.title((salaries.groupby('salary').native_country_summary.value_counts()/salaries.groupby('salary').size()).index.get_level_values(0)[i])

    index+=1

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/QHc8m0x/85.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** .................

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
# Your Code is Here

age_mean = salaries.groupby(['salary', 'sex']).age.mean()

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(6,4))


ax = age_mean.plot.bar();

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f')

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/BBDy081/86.png)

# %%
# Your Code is Here

age_mean.reset_index()
# Out:
#   salary     sex    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4PD1208/87.png)

# %%
# Your Code is Here
fig, ax =  plt.subplots(figsize=(6,4)); start, end, steps = 0, 40, 5
ax = sns.barplot(data=salaries, x='salary', y='age',  hue='sex', ci=None, hue_order=['Female', 'Male']);
yticks = np.linspace(start, end, steps)
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f')



plt.xticks(rotation=0, fontsize=7)
plt.yticks(yticks, rotation=0,fontsize=7)

plt.xlabel('Salary', fontsize=7)
plt.ylabel('Count', fontsize=7)

plt.legend(loc='upper left', fontsize=7, title='gender', title_fontsize=7)

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/2n0yGt7/88.png)

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
# Your Code is Here

a = salaries[(salaries.salary=='>50K')&(salaries.native_country=='United-States')]['workclass'].value_counts(normalize=True)*100

# %%
salaries
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical         Unkown  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary  \
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
#           education_level    married
# 0        high_level_grade  unmarried
# 1        high_level_grade    married
# 2      medium_level_grade  unmarried
# 3         low_level_grade    married
# 4        high_level_grade    married
# ...                   ...        ...
# 32556  medium_level_grade    married
# 32557  medium_level_grade    married
# 32558  medium_level_grade  unmarried
# 32559  medium_level_grade  unmarried
# 32560  medium_level_grade    married
#
# [32537 rows x 17 columns]

# %% [raw]
# Desired Output:
#
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: workclass, dtype: float64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(6,4))

ax = sns.barplot(x=a.index, y=a.values)

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f')
    
    
plt.xticks(rotation=90, fontsize=7);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/gMHzLgH/89.png)

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
# Your Code is Here

a = salaries[(salaries.salary=='>50K')&(salaries.native_country=='United-States')&(salaries.workclass == 'Private')].occupation.value_counts(normalize=True)*100
a
# Out:
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %% [raw]
# Desired Output:
#
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
# Your Code is Here
fig, ax = plt.subplots(figsize=(6,4))

ax = sns.barplot(x=a.index, y=a.values)

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', fontsize=7)
plt.xticks(rotation=90, fontsize=7);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/s3Kd7VS/90.png)

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
# Your Code is Here

a = salaries[(salaries.salary=='>50K')&(salaries.race=='Asian-Pac-Islander')].education.value_counts(normalize=True)*100
a
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %% [raw]
# Desired Output:
#
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(6,4))

ax = sns.barplot(x=a.index, y=a.values)

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', fontsize=7)

plt.xticks(rotation=90, fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/rZnSFBX/91.png)

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
# Your Code is Here

a = salaries[(salaries.salary=='>50K')&(salaries.race=='Asian-Pac-Islander')&(salaries.education=='Bachelors')].occupation.value_counts(normalize=True)*100
a
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %% [raw]
# Desired Output:
#
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(6,4))

ax = sns.barplot(x=a.index, y=a.values)

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', fontsize=7)

plt.xticks(rotation=90, fontsize=7)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/zZVsbJf/92.png)

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
# Your Code is Here


ax = sns.catplot(x='education_level', 
            y='hours_per_week', 
            kind='bar', 
            hue='sex', 
            row='new_c', 
            col='married', 
            data=salaries[(salaries.race == 'Other')],
            ci=None);


for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', fontsize=7)

# %%
salaries['new_c'] = salaries.native_country.apply(lambda x : x if x == 'United-States' else 'Others' )

# %%
salaries.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary', 'education_level', 'married'],
#       dtype='object')

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/G5KY8nf/93.png)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# Your Code is Here

salaries.isnull().sum()
# Out:
# age                         0
# workclass                   0
# fnlwgt                      0
# education                   0
# education_num             802
# marital_status              0
# occupation                  0
# relationship                0
# race                        0
# sex                         0
# capital_gain                0
# capital_loss                0
# hours_per_week              0
# native_country              0
# salary                      0
# education_level             0
# married                     0
# native_country_summary      0
# dtype: int64

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   gender                  32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
#  14  salary                  32537 non-null  object
#  15  education_summary       32537 non-null  object
#  16  marital_status_summary  32537 non-null  object
#  17  native_country_summary  32537 non-null  object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 5.7+ MB

# %%
# Drop the columns of "education", "education_num", "relationship", "marital_status", "native_country" permanently

# Your Code is Here

salaries.drop(["education", "education_num", "relationship", "marital_status", "native_country"], axis=1, inplace=True)
salaries
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary     education_level  \
# 0              2174             0              40  <=50K    high_level_grade
# 1                 0             0              13  <=50K    high_level_grade
# 2                 0             0              40  <=50K  medium_level_grade
# 3                 0             0              40  <=50K     low_level_grade
# 4                 0             0              40  <=50K    high_level_grade
# ...             ...           ...             ...    ...                 ...
# 32556             0             0              38  <=50K  medium_level_grade
# 32557             0             0              40   >50K  medium_level_grade
# 32558             0             0              40  <=50K  medium_level_grade
# 32559             0             0              20  <=50K  medium_level_grade
# 32560         15024             0              40   >50K  medium_level_grade
#
#          married native_country_summary
# 0      unmarried                     US
# 1        married                     US
# 2      unmarried                     US
# 3        married                     US
# 4        married                 Others
# ...          ...                    ...
# 32556    married                     US
# 32557    married                     US
# 32558  unmarried                     US
# 32559  unmarried                     US
# 32560    married                     US
#
# [32537 rows x 13 columns]

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %%
# Your Code is Here

salaries.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_level           0
# married                   0
# native_country_summary    0
# dtype: int64

# %% [raw]
# Desired Output:
#
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# Unknown         1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
# Replace "Unknown" values with NaN using numpy library

# Your Code is Here

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# gender                       0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %%
# Drop missing values in df permanently

# Your Code is Here

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   gender                  30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### Boxplot and Histplot for all numeric features
#
# **Plot boxplots for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/DKMSBDk/94.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JKtcs9S/95.png)

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/fMpP3yR/96.png)

# %% [markdown]
# **Check the statistical values for all numeric features**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/t3MJHDr/97.png)

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/SnzH5Nz/98.png)

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (28.0, 47.0, 19.0)

# %%
# Find lower and upper limit using IQR

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (-0.5, 75.5)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 90    35
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
# Define the observations whose age is greater than upper limit and sort these observations by age in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x2wDgzQ/99.png)

# %% [markdown]
# ### hours_per_week

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xq53X6w/100.png)

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (40.0, 45.0, 5.0)

# %%
# Find the lower and upper limit using IQR

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (32.5, 52.5)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/zGCnbjz/101.png)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/swYNtdM/102.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/S7RWpxD/103.png)

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
# Create a condition according to your domain knowledge on age stated above and 
# sort the observations meeting this condition by age in ascending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/pJC50ZV/104.png)

# %%
# Find the shape of the dataframe created by the condition defined above for age 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (76, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for age

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([  222, 18832, 10545, 11512, 11996, 12975, 14159, 15892, 18277,
#             18413, 18725, 19212,  8973, 19489, 19747, 20610, 22220, 24043,
#             28463, 31030, 32277, 32367, 10210, 15356,  5370,  4070,  1040,
#              6232,  1935,  2303,  5272,  6624,  2891,  5406,  8806,  1168,
#             22895, 21835, 24027, 20463,  8381, 32459, 26731, 27795,  9471,
#              6214, 14711, 11238,  7720, 15662,  7481, 24395, 23459, 19172,
#             16302, 14756,  8431, 20421, 22481, 31855, 13696, 24280,  4834,
#             29594, 28948, 12830,   918, 13295, 24560,  3537, 13928, 19045,
#              6748,  2906, 21501, 19495],
#            dtype='int64')

# %%
# Drop these indices defined above for age

# Your Code is Here

# %%
# Create a condition according to your domain knowledge on hours per week stated above and 
# sort the observations meeting this condition by hours per week in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/rMp7C58/105.png)

# %%
# Find the shape of the dataframe created by the condition defined above for hours per week 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (621, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for hours per week

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
# Drop these indices defined above for hours per week

# Your Code is Here

# %%
# Create a condition according to your domain knowledge on both age and hours per week stated above 

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Ch8XSdW/106.png)

# %%
# Find the shape of the dataframe created by the condition defined above for both age and hours per week


# Your Code is Here

# %% [raw]
# Desired Output:
#
# (23, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for both age and hours per week

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
# Drop these indices defined above for both age and hours per week

# Your Code is Here

# %%
# What is new shape of dataframe now

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 13)

# %%
# Reset the indices and take the head of DataFrame now

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5MXPD2b/107.png)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29969    0
# 29970    1
# 29971    0
# 29972    0
# 29973    1
# Name: salary, Length: 29974, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 0    22524
# 1     7450
# Name: salary, dtype: int64

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0F1SHRt/108.png)

# %%
# What's the shape of dataframe

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 13)

# %%
# What's the shape of dataframe created by dummy operation

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 34)

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Dgb8RYZ/109.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5XH3X4q/110.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/19RytkS/111.png)

# %%
# Your Code is Here

# %% [markdown]
# ![image.png](https://i.ibb.co/80GcYKr/112.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0MCPc4d/113.png)

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
