# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       3 # Load the CSV file
# ----> 4 data = np.genfromtxt('https://raw.githubusercontent.com/4aks4/Cohort006/main/Cohort006/Assignments/Salaries.csv', delimiter=',', dtype=str, skip_header=1)
#       6 # Extract the salary column and convert to float
#       7 salary = data[:, 2].astype(float)
#
# File c:\Users\ahmet\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\npyio.py:2309, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    2307 # Raise an exception ?
#    2308 if invalid_raise:
# -> 2309     raise ValueError(errmsg)
# ...
